# %% [markdown]
# 1. number (int/float/double)
# 2. string (text utf-8)
# 3. booleans (true/false)
#
# ---
#
# single
# - color
# - runitme in seconds 15s
# - how many times to retrty 3 5 7
# - id person = 20385
# - credit card num
# - isHePayed = True
#
# groups
#
# user
#  - name
#  - id
#  - creditcard
#  - isGrandfather
#  - isRobotFake

# %%
# these are vars - variables
my_num = 5
my_hex = 0xFF
# let long int myvar = 1000000000000000
my_str = "Im the best" #str
my_char = "s" #char
my_boolean = True # false
print(my_hex) #console.log()
# Out:
# 255

# %% [markdown]
# # Dictionary - hashmap - map -json
# my_dictionary = {
#     "nameKey" : "nameValue",
#     "idKey": "idValue",
#     "isSignedInKey": "isSignedInValue"
# }

# %%
my_dictionary = {
    "nameKey" : "nameValue",
    "idKey": "idValue",
    "isSignedInKey": "isSignedInValue" 
}
print(my_dictionary["idValue"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 6
#       2     "nameKey" : "nameValue",
#       3     "idKey": "idValue",
#       4     "isSignedInKey": "isSignedInValue"
#       5 }
# ----> 6 print(my_dictionary["idValue"])
#
# KeyError: 'idValue'

# %% [markdown]
# List

# %%
my_list = ["art", "anime", "coding", "gaming", "music"]
#           0       1         2         3         4
print(my_list)
# Out:
# ['art', 'anime', 'coding', 'gaming', 'music']

# %%
records = [
    {
        "name": "grego",
        "id": 1234,
        "isSignedIn": True
    },
    {
        "name": "grego2",
        "id": 12345,
        "isSignedIn": False
    }
]
print(records)
# Out:
# [{'name': 'grego', 'id': 1234, 'isSignedIn': True}, {'name': 'grego2', 'id': 12345, 'isSignedIn': False}]
